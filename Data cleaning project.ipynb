# %%
import pandas as pd

# %%
df=pd.read_excel('Nashville Housing Data for Data Cleaning.xlsx')

# %%
df.shape
# Out:
# (56477, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  int64
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  datetime64[ns]
#  5   SalePrice        56477 non-null  int64
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
# ...

# %%
df.head()
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  20130412-0036474
# 1  1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  20140619-0053768
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  20160927-0101718
# 3  1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  20160129-0008913
# 4  1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate',
#        'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName',
#        'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue',
#        'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
df['UniqueID ']=df['UniqueID '].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  object
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  datetime64[ns]
#  5   SalePrice        56477 non-null  int64
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
# ...

# %%
##df['YearBuilt']=df['YearBuilt'].astype('int64')

# %%
df['SaleDate']=df['SaleDate'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  object
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  object
#  5   SalePrice        56477 non-null  int64
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
# ...

# %%
df.head()
# Out:
#   UniqueID          ParcelID        LandUse  \
# 0      2045  007 00 0 125.00  SINGLE FAMILY
# 1     16918  007 00 0 130.00  SINGLE FAMILY
# 2     54582  007 00 0 138.00  SINGLE FAMILY
# 3     43070  007 00 0 143.00  SINGLE FAMILY
# 4     22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress    SaleDate  SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE  2013-04-09     240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE  2014-06-10     366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  2016-09-26     435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE  2016-01-29     255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE  2014-10-10     278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df['SalesYear']=df['SaleDate'].str.split('-',expand=True)[0]

# %%
df['SalesMonth']=df['SaleDate'].str.split('-',expand=True)[1]

# %%
df['SalesDay']=df['SaleDate'].str.split('-',expand=True)[2]

# %%
df.head()
# Out:
#   UniqueID          ParcelID        LandUse  \
# 0      2045  007 00 0 125.00  SINGLE FAMILY
# 1     16918  007 00 0 130.00  SINGLE FAMILY
# 2     54582  007 00 0 138.00  SINGLE FAMILY
# 3     43070  007 00 0 143.00  SINGLE FAMILY
# 4     22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress    SaleDate  SalePrice  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE  2013-04-09     240000
# 1  1832  FOX CHASE DR, GOODLETTSVILLE  2014-06-10     366000
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  2016-09-26     435000
# 3  1853  FOX CHASE DR, GOODLETTSVILLE  2016-01-29     255000
# 4  1829  FOX CHASE DR, GOODLETTSVILLE  2014-10-10     278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# ...

# %%
df.drop(columns=['SaleDate'],inplace=True)

# %%
df['1']=df['PropertyAddress'].str.split(',',expand=True)[0]

# %%
df['2']=df['PropertyAddress'].str.split(',',expand=True)[1]

# %%
df.rename(columns={'1':'PropertyStreet'},inplace=True)

# %%
df.rename(columns={'2':'PropertyCity'},inplace=True)

# %%
df.drop(columns=['PropertyAddress'], inplace=True)

# %%
df.head()
# Out:
#   UniqueID          ParcelID        LandUse  SalePrice    LegalReference  \
# 0      2045  007 00 0 125.00  SINGLE FAMILY     240000  20130412-0036474
# 1     16918  007 00 0 130.00  SINGLE FAMILY     366000  20140619-0053768
# 2     54582  007 00 0 138.00  SINGLE FAMILY     435000  20160927-0101718
# 3     43070  007 00 0 143.00  SINGLE FAMILY     255000  20160129-0008913
# 4     22714  007 00 0 149.00  SINGLE FAMILY     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# 3           No            BAKER, JAY K. & SUSAN E.
# 4           No  POST, CHRISTOPHER M. & SAMANTHA C.
#
#                              OwnerAddress  Acreage                TaxDistrict  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3  GENERAL SERVICES DISTRICT
# ...

# %%
df.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'SalePrice', 'LegalReference',
#        'SoldAsVacant', 'OwnerName', 'OwnerAddress', 'Acreage', 'TaxDistrict',
#        'LandValue', 'BuildingValue', 'TotalValue', 'YearBuilt', 'Bedrooms',
#        'FullBath', 'HalfBath', 'SalesYear', 'SalesMonth', 'SalesDay',
#        'PropertyStreet', 'PropertyCity'],
#       dtype='object')

# %%
pd.options.display.max_columns=100

# %%
df.head()
# Out:
#   UniqueID          ParcelID        LandUse  SalePrice    LegalReference  \
# 0      2045  007 00 0 125.00  SINGLE FAMILY     240000  20130412-0036474
# 1     16918  007 00 0 130.00  SINGLE FAMILY     366000  20140619-0053768
# 2     54582  007 00 0 138.00  SINGLE FAMILY     435000  20160927-0101718
# 3     43070  007 00 0 143.00  SINGLE FAMILY     255000  20160129-0008913
# 4     22714  007 00 0 149.00  SINGLE FAMILY     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# 3           No            BAKER, JAY K. & SUSAN E.
# 4           No  POST, CHRISTOPHER M. & SAMANTHA C.
#
#                              OwnerAddress  Acreage                TaxDistrict  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3  GENERAL SERVICES DISTRICT
# ...

# %%
df["Owner'Street"]=df['OwnerAddress'].str.split(',',expand=True)[0]

# %%
df["Owner'sCity"]=df['OwnerAddress'].str.split(',',expand=True)[1]

# %%
df["Owner'sLAst level"]=df['OwnerAddress'].str.split(',',expand=True)[2]

# %%
df.drop(columns=['OwnerAddress'],inplace=True)

# %%
df.head()
# Out:
#   UniqueID          ParcelID        LandUse  SalePrice    LegalReference  \
# 0      2045  007 00 0 125.00  SINGLE FAMILY     240000  20130412-0036474
# 1     16918  007 00 0 130.00  SINGLE FAMILY     366000  20140619-0053768
# 2     54582  007 00 0 138.00  SINGLE FAMILY     435000  20160927-0101718
# 3     43070  007 00 0 143.00  SINGLE FAMILY     255000  20160129-0008913
# 4     22714  007 00 0 149.00  SINGLE FAMILY     278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  Acreage  \
# 0           No           FRAZIER, CYRENTHA LYNETTE      2.3
# 1           No             BONER, CHARLES & LESLIE      3.5
# 2           No           WILSON, JAMES E. & JOANNE      2.9
# 3           No            BAKER, JAY K. & SUSAN E.      2.6
# 4           No  POST, CHRISTOPHER M. & SAMANTHA C.      2.0
#
#                  TaxDistrict  LandValue  BuildingValue  TotalValue  YearBuilt  \
# 0  GENERAL SERVICES DISTRICT    50000.0       168200.0    235700.0     1986.0
# ...

# %%
df['SoldAsVacant'].unique()
# Out:
# array(['No', 'N', 'Yes', 'Y'], dtype=object)

# %%
df['SoldAsVacant']=df['SoldAsVacant'].replace("^'N'$","'No'",regex=True)

# %%
df['SoldAsVacant']=df['SoldAsVacant'].replace("^'Y'$","'Yes'",regex=True)

# %%
df['SoldAsVacant'].unique()
# Out:
# array(['No', 'N', 'Yes', 'Y'], dtype=object)

# %%
df.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'SalePrice', 'LegalReference',
#        'SoldAsVacant', 'OwnerName', 'Acreage', 'TaxDistrict', 'LandValue',
#        'BuildingValue', 'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath',
#        'HalfBath', 'SalesYear', 'SalesMonth', 'SalesDay', 'PropertyStreet',
#        'PropertyCity', 'Owner'Street', 'Owner'sCity', 'Owner'sLAst level'],
#       dtype='object')
